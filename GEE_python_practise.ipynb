# %%
# %pip install earthengine-api -q
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install geemap
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import ee
ee.Authenticate()
# Out:
# <p>To authorize access needed by Earth Engine, open the following
#         URL in a web browser and follow the instructions:</p>
#         <p><a href=https://code.earthengine.google.com/client-auth?scopes=https%3A//www.googleapis.com/auth/earthengine%20https%3A//www.googleapis.com/auth/cloud-platform%20https%3A//www.googleapis.com/auth/drive%20https%3A//www.googleapis.com/auth/devstorage.full_control&request_id=ID-AVxlzBv-73mki0fOJr_mXPSDNU-pDp1Yfhs52p84&tc=s_7sk47HcAiq7fHluD1555jeCkVGt2kGvmOJVaG9Tok&cc=yonDhSvKIvmBLNm42blPYmeG2l5jLE5smpsZyWlYWBM>https://code.earthengine.google.com/client-auth?scopes=https%3A//www.googleapis.com/auth/earthengine%20https%3A//www.googleapis.com/auth/cloud-platform%20https%3A//www.googleapis.com/auth/drive%20https%3A//www.googleapis.com/auth/devstorage.full_control&request_id=ID-AVxlzBv-73mki0fOJr_mXPSDNU-pDp1Yfhs52p84&tc=s_7sk47HcAiq7fHluD1555jeCkVGt2kGvmOJVaG9Tok&cc=yonDhSvKIvmBLNm42blPYmeG2l5jLE5smpsZyWlYWBM</a></p>
# ...

# %%
4/1AXEQxICNGm197LFxXO0LEPya480FxiCfeINdvy7piZa3MoAa0cIZuSbeYps

# %%
import ee 
import geemap
dataset = ee.ImageCollection('AAFC/ACI')
crop_2016 = dataset.filter(ee.Filter.date('2016-01-01', '2016-12-31')).first()

m = geemap.Map()
m.set_center(-103.8881, 53.0372, 10)
m.add_layer(crop_2016, {}, '2016 Canada AAFC Annual Crop Inventory')
# Out:
# ---------------------------------------------------------------------------
# EEException                               Traceback (most recent call last)
# Cell In[5], line 3
#       1 import ee
#       2 import geemap
# ----> 3 dataset = ee.ImageCollection('AAFC/ACI')
#       4 crop_2016 = dataset.filter(ee.Filter.date('2016-01-01', '2016-12-31')).first()
#       5
#       6 m = geemap.Map()
#
# File c:\Users\loung\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\ee\computedobject.py:29, in ComputedObjectMetaclass.__call__(cls, *args, **kwargs)
#      27   return args[0]
#      28 else:
# ---> 29   return type.__call__(cls, *args, **kwargs)
#
# File c:\Users\loung\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\ee\deprecation.py:127, in WarnForDeprecatedAsset.<locals>.Decorator.<locals>.Wrapper(*args, **kwargs)
#     125   if asset:
#     126     _IssueAssetDeprecationWarning(asset)
# --> 127 return func(*args, **kwargs)
#
# ...
